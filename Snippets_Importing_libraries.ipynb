# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaronlinke/AI-Ecosystem/blob/master/Snippets_Importing_libraries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing a library that is not in Colaboratory
#
# To import a library that's not in Colaboratory by default, you can use `!pip install` or `!apt-get install`.

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# %cd /content/BitCrack-extracted/BitCrack-master
# Wir nutzen -j, um alle CPU-Kerne für eine schnellere Kompilierung zu verwenden
# !make -j$(nproc)
# !if [ -f "./BitCrack" ]; then echo "FERTIG! BitCrack wurde erstellt."; ls -l BitCrack; else echo "Immer noch am Bauen..."; fi
# Out:
# /content/BitCrack-extracted/BitCrack-master
# make --directory util
# make --directory CryptoUtil
# make[1]: warning: jobserver unavailable: using -j1.  Add '+' to parent make rule.
# make[1]: Entering directory '/content/BitCrack-extracted/BitCrack-master/util'
# for file in util.cpp ; do\
# ...

# %%
# Wir definieren eine Test-Adresse zum Ausprobieren
meine_test_adresse = "1PWo3JeB9jrGwfHDNpdGK54CRas7fsVzXU"

# !if [ -f "./BitCrack" ]; then \
    echo "--- BitCrack Hilfe --- "; \
    ./BitCrack --help; \
    echo "\n--- Testlauf (CPU/OpenCL Modus) ---"; \
    ./BitCrack -c -t 1 $meine_test_adresse; \
else \
    echo "Bitte warten Sie, bis der 'make' Befehl in der Zelle darüber fertig ist (das kann 1-2 Minuten dauern)."; \
fi
# Out:
# Bitte warten Sie, bis der 'make' Befehl in der Zelle darüber fertig ist (das kann 1-2 Minuten dauern).

# %%
# !unzip -q /content/BitCrack-master.zip -d /content/BitCrack-extracted
import os

# Liste der entpackten Dateien anzeigen
for root, dirs, files in os.walk('/content/BitCrack-extracted'):
    for file in files:
        print(os.path.join(root, file))
# Out:
# /content/BitCrack-extracted/BitCrack-master/README.md
# /content/BitCrack-extracted/BitCrack-master/.gitattributes
# /content/BitCrack-extracted/BitCrack-master/LICENSE.MIT
# /content/BitCrack-extracted/BitCrack-master/.gitignore
# /content/BitCrack-extracted/BitCrack-master/BitCrack.sln
# /content/BitCrack-extracted/BitCrack-master/Makefile
# /content/BitCrack-extracted/BitCrack-master/BitCrack.props
# /content/BitCrack-extracted/BitCrack-master/CryptoUtil/CryptoUtil.h
# /content/BitCrack-extracted/BitCrack-master/CryptoUtil/ripemd160.cpp
# /content/BitCrack-extracted/BitCrack-master/CryptoUtil/sha256.cpp
# /content/BitCrack-extracted/BitCrack-master/CryptoUtil/Rng.cpp
# /content/BitCrack-extracted/BitCrack-master/CryptoUtil/Makefile
# /content/BitCrack-extracted/BitCrack-master/CryptoUtil/checksum.cpp
# /content/BitCrack-extracted/BitCrack-master/CryptoUtil/CryptoUtil.vcxproj
# /content/BitCrack-extracted/BitCrack-master/CryptoUtil/hash.cpp
# ...

# %%
# !pip install matplotlib-venn

# %%
# !apt-get -qq install -y libfluidsynth1

# %% [markdown]
# # Install 7zip reader [libarchive](https://pypi.python.org/pypi/libarchive)

# %%
# https://pypi.python.org/pypi/libarchive
# !apt-get -qq install -y libarchive-dev && pip install -U libarchive
import libarchive

# %% [markdown]
# # Install GraphViz & [PyDot](https://pypi.python.org/pypi/pydot)

# %%
# https://pypi.python.org/pypi/pydot
# !apt-get -qq install -y graphviz && pip install pydot
import pydot

# %% [markdown]
# # Install [cartopy](http://scitools.org.uk/cartopy/docs/latest/)

# %%
# !pip install cartopy
import cartopy
